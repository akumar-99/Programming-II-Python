# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
characters_df = pd.read_csv("./characters_stats.csv")

# %%
characters_df
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            A-Bomb      good            38       100     17          80
# 1      Adam Strange      good             1         1      1           1
# 2         Agent  13      good             1         1      1           1
# 3        Agent Zero      good            75        28     38          80
# 4        Alan Scott      good            63        80     23          90
# ..              ...       ...           ...       ...    ...         ...
# 188  Winter Soldier      good            56        32     35          65
# 189       Wolverine      good            55        32     38         100
# 190    Wonder Woman      good            88       100     50         100
# 191    Yellowjacket      good            88        10     12          28
# 192               y      good            75        10     23          28
#
#      Power  Combat  Total
# 0       17      64    316
# 1        0       1      5
# ...

# %%
# characters_df.shape[0]
characters_df.reset_index(drop=True)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            A-Bomb      good            38       100     17          80
# 1      Adam Strange      good             1         1      1           1
# 2         Agent  13      good             1         1      1           1
# 3        Agent Zero      good            75        28     38          80
# 4        Alan Scott      good            63        80     23          90
# ..              ...       ...           ...       ...    ...         ...
# 188  Winter Soldier      good            56        32     35          65
# 189       Wolverine      good            55        32     38         100
# 190    Wonder Woman      good            88       100     50         100
# 191    Yellowjacket      good            88        10     12          28
# 192               y      good            75        10     23          28
#
#      Power  Combat  Total
# 0       17      64    316
# 1        0       1      5
# ...

# %%
# df1 = characters_df['Name'].str.contains("Zatanna")
# type(df1)
# df = characters_df['Name']=='Zatanna'
# type(df)

def hero_exists(hero_name):
    flag = False
    for name in characters_df['Name']:
        if name==hero_name:
            return True
    else:
        return False
hero_exists("Yellowjacket")
# Out:
# True

# %%
characters_df.index[characters_df['Name'] == "x"].tolist()[0]
# Out:
# 194

# %%
df1 = pd.DataFrame({"Name":[name.get(),], "Alignment":[alignment.get(),], "Intelligence":[intelligence.get(),], "Strength":[strength.get(),], "Speed":[speed.get(),], "Durability":[durability.get(),], "Power":[power.get(),], "Combat":[combat.get(),], "Total":[intelligence.get()+strength.get()+speed.get()+durability.get()+power.get()+combat.get()]})

characters_df = characters_df.append(df1, ignore_index = True)

# %%
name_arr=[]
for val in characters_arr:
    name_arr.append(val[0])

# %%
len(characters_arr)
name_arr = characters_arr[0]

# %%
name_arr
# Out:
# array(['A-Bomb', 'good', 38, 100, 17, 80, 17, 64, 316], dtype=object)

# %%
import tkinter as tk
from tkinter import ttk
from tkinter import messagebox
form = tk.Tk()
form.title("SUPER HEROES")
# form.geometory("1024*768")
form.resizable(True, True)

tab_parent = ttk.Notebook(form)
tab_parent.pack(expand = 1, fill='both')

tab1 = tk.Frame(tab_parent)
tab2 = tk.Frame(tab_parent)

tab_parent.add(tab1, text = "TAB1")
tab_parent.add(tab2, text = "TAB2")


label_name = tk.Label(tab1, text = "NAME", font=("cambria",13,"bold"), bg="black",fg="white", width = 20, anchor = 'c')
label_name.grid(column = 0, row = 0, padx = 8, pady = 4)
name = tk.StringVar()
nameEntered = tk.Entry(tab1, textvariable = name, width = 45, font=("arial black",13),bg="orange")
nameEntered.grid(column = 1, row = 0, columnspan=3)

label_alignment = tk.Label(tab1, text = "ALIGNMENT", font=("cambria",13,"bold"), bg="black",fg="white", width = 20, anchor = 'c')
label_alignment.grid(column = 0, row = 1, padx = 8, pady = 4)
alignment = tk.StringVar()
alignmentEntered = tk.Entry(tab1, textvariable = alignment, font=("arial black",13),bg="orange")
alignmentEntered.grid(column = 1, row = 1, columnspan=3)

label_intelligence = tk.Label(tab1, text = "INTELLIGENCE", font=("cambria",13,"bold"), bg="black",fg="white", width = 20, anchor = 'c')
label_intelligence.grid(column = 0, row = 2, padx = 8, pady = 4)
intelligence = tk.IntVar()
intelligenceEntered = tk.Entry(tab1, textvariable = intelligence, font=("arial black",13),bg="orange")
intelligenceEntered.grid(column = 1, row = 2, columnspan=3)

label_strength = tk.Label(tab1, text = "STRENGTH", font=("cambria",13,"bold"), bg="black",fg="white", width = 20, anchor = 'c')
label_strength.grid(column = 0, row = 3, padx = 8, pady = 4)
strength = tk.IntVar()
strengthEntered = tk.Entry(tab1, textvariable = strength, font=("arial black",13),bg="orange")
strengthEntered.grid(column = 1, row = 3, columnspan=3)

label_speed = tk.Label(tab1, text = "SPEED", font=("cambria",13,"bold"), bg="black",fg="white", width = 20, anchor = 'c')
label_speed.grid(column = 0, row = 4, padx = 8, pady = 4)
speed = tk.IntVar()
speedEntered = tk.Entry(tab1, textvariable = speed, font=("arial black",13),bg="orange")
speedEntered.grid(column = 1, row = 4, columnspan=3)

label_durability = tk.Label(tab1, text = "DURABILITY", font=("cambria",13,"bold"), bg="black",fg="white", width = 20, anchor = 'c')
label_durability.grid(column = 0, row = 5, padx = 8, pady = 4)
durability = tk.IntVar()
durabilityEntered = tk.Entry(tab1, textvariable = durability, font=("arial black",13),bg="orange")
durabilityEntered.grid(column = 1, row = 5, columnspan=3)

label_power = tk.Label(tab1, text = "POWER", font=("cambria",13,"bold"), bg="black",fg="white", width = 20, anchor = 'c')
label_power.grid(column = 0, row = 6, padx = 8, pady = 4)
power = tk.IntVar()
powerEntered = tk.Entry(tab1, textvariable = power, font=("arial black",13),bg="orange")
powerEntered.grid(column = 1, row = 6, columnspan=3)

label_combat = tk.Label(tab1, text = "COMBAT", font=("cambria",13,"bold"), bg="black",fg="white", width = 20, anchor = 'c')
label_combat.grid(column = 0, row = 7, padx = 8, pady = 4)
combat = tk.IntVar()
combatEntered = tk.Entry(tab1, textvariable = combat, font=("arial black",13),bg="orange")
combatEntered.grid(column = 1, row = 7, columnspan=3)

label_total = tk.Label(tab1, text = "TOTAL", font=("cambria",13,"bold"), bg="black",fg="white", width = 20, anchor = 'c')
label_total.grid(column = 0, row = 8, padx = 8, pady = 4)
total = tk.IntVar()
totalEntered = tk.Entry(tab1, textvariable = total, font=("arial black",13),bg="orange",  state='disabled')
totalEntered.grid(column = 1, row = 8, columnspan=3)

count = 0
tot_rec = characters_df.shape[0]

def firstRec():
    global count
    global tot_rec
    count = 0
    tot_rec = characters_df.shape[0]
    name.set(characters_df.at[count, "Name"])
    alignment.set(characters_df.at[count, "Alignment"])
    intelligence.set(characters_df.at[count, "Intelligence"])
    strength.set(characters_df.at[count, "Strength"])
    speed.set(characters_df.at[count, "Speed"])
    durability.set(characters_df.at[count, "Durability"])
    power.set(characters_df.at[count, "Power"])
    combat.set(characters_df.at[count, "Combat"])
    total.set(characters_df.at[count, "Total"])
    l5.configure(text=str(count+1)+"/"+str(tot_rec))
def preRec():
    global count
    global tot_rec
    if count == 0:
         tk.messagebox.showinfo("WARNING", "Already on first record")
    else:
        count -= 1
        tot_rec = characters_df.shape[0]
        name.set(characters_df.at[count, "Name"])
        alignment.set(characters_df.at[count, "Alignment"])
        intelligence.set(characters_df.at[count, "Intelligence"])
        strength.set(characters_df.at[count, "Strength"])
        speed.set(characters_df.at[count, "Speed"])
        durability.set(characters_df.at[count, "Durability"])
        power.set(characters_df.at[count, "Power"])
        combat.set(characters_df.at[count, "Combat"])
        total.set(characters_df.at[count, "Total"])
        l5.configure(text=str(count+1)+"/"+str(tot_rec))
def nextRec():
    global count
    global tot_rec
    if count == tot_rec-1:
         tk.messagebox.showinfo("WARNING", "Already on last record")
    else:
        count += 1
        tot_rec = characters_df.shape[0]
        name.set(characters_df.at[count, "Name"])
        alignment.set(characters_df.at[count, "Alignment"])
        intelligence.set(characters_df.at[count, "Intelligence"])
        strength.set(characters_df.at[count, "Strength"])
        speed.set(characters_df.at[count, "Speed"])
        durability.set(characters_df.at[count, "Durability"])
        power.set(characters_df.at[count, "Power"])
        combat.set(characters_df.at[count, "Combat"])
        total.set(characters_df.at[count, "Total"])
        l5.configure(text=str(count+1)+"/"+str(tot_rec))
def lastRec():
    global count
    global tot_rec
    tot_rec = characters_df.shape[0]
    count = characters_df.shape[0] - 1
    name.set(characters_df.at[count, "Name"])
    alignment.set(characters_df.at[count, "Alignment"])
    intelligence.set(characters_df.at[count, "Intelligence"])
    strength.set(characters_df.at[count, "Strength"])
    speed.set(characters_df.at[count, "Speed"])
    durability.set(characters_df.at[count, "Durability"])
    power.set(characters_df.at[count, "Power"])
    combat.set(characters_df.at[count, "Combat"])
    total.set(characters_df.at[count, "Total"])
    
    l5.configure(text=str(count+1)+"/"+str(tot_rec))
    
def hero_exists(hero_name):
    flag = False
    for name in characters_df['Name']:
        if name==hero_name:
            return True
    else:
        return False
            
def addRec():
    global count
    global characters_df
    global total_rec
    flag = False
    if hero_exists(name.get()) == True:
        messagebox.showinfo("MESSAGE", "SuperHero already exists")
    else:
        df1 = pd.DataFrame({"Name":[name.get(),], "Alignment":[alignment.get(),], "Intelligence":[intelligence.get(),], "Strength":[strength.get(),], "Speed":[speed.get(),], "Durability":[durability.get(),], "Power":[power.get(),], "Combat":[combat.get(),], "Total":[intelligence.get()+strength.get()+speed.get()+durability.get()+power.get()+combat.get()]})
        total.set(intelligence.get()+strength.get()+speed.get()+durability.get()+power.get()+combat.get())
        characters_df = characters_df.append(df1, ignore_index = True) 
        tot_rec = characters_df.shape[0]
        count = characters_df.shape[0] - 1
        l5.configure(text=str(count+1)+"/"+str(tot_rec))
        messagebox.showinfo("MESSAGE", "Addition Successful")
        characters_df.to_csv('./characters_stats.csv') 
#         clear()
def delRec():
    global count
    global characters_df
    if hero_exists(name.get()) == False:
        messagebox.showinfo("MESSAGE", "SuperHero does not exist")
    else:
        characters_df = characters_df.drop(characters_df.index[characters_df['Name'] == name.get()].tolist()[0])
        characters_df = characters_df.reset_index(drop=True)
        count = 0
        tot_rec = characters_df.shape[0]
        l5.configure(text=str(count)+"/"+str(tot_rec))
        characters_df.to_csv('./characters_stats.csv') 
        messagebox.showinfo("MESSAGE", "Deletion Successful")
        clear()
        
# Cannot update name
def updateRec():
    global count
    global characters_df
    if hero_exists(name.get()) == False:
        messagebox.showinfo("MESSAGE", "SuperHero does not exist")
    else:
        row_index = characters_df.index[characters_df['Name'] == name.get()].tolist()[0]
        characters_df.at[count, "Name"]
        characters_df.at[count, "Alignment"]
        characters_df.at[count, "Intelligence"]
        characters_df.at[count, "Strength"]
        characters_df.at[count, "Speed"]
        characters_df.at[count, "Durability"]
        characters_df.at[count, "Power"]
        characters_df.at[count, "Combat"]
        characters_df.at[count, "Total"]
                 
        characters_df = characters_df.drop(characters_df.index[characters_df['Name'] == name.get()].tolist()[0])
        characters_df = characters_df.reset_index(drop=True)
        count = 0
        tot_rec = characters_df.shape[0]
        l5.configure(text=str(count)+"/"+str(tot_rec))
        characters_df.to_csv('./characters_stats.csv') 
        messagebox.showinfo("MESSAGE", "Deletion Successful")
        clear()
def searchRec():
    a = 5
def clear():
    nameEntered.delete(first=0, last=999)
    alignmentEntered.delete(first=0, last=999)
    intelligenceEntered.delete(first=0, last=999)
    strengthEntered.delete(first=0, last=999)
    speedEntered.delete(first=0, last=999)
    durabilityEntered.delete(first=0, last=999)
    powerEntered.delete(first=0, last=999)
    combatEntered.delete(first=0, last=999)
    totalEntered.delete(first=0, last=999)
clear()

b1 = tk.Button(tab1, width="8", text="|<", command=firstRec, font=("cambria",13,"bold"))
b1.grid(row=9, column=0, padx=10, pady=10)
b2 = tk.Button(tab1, width="8", text="<", command=preRec, font=("cambria",13,"bold"))
b2.grid(row=9, column=1)
b3 = tk.Button(tab1, width="8", text=">", command=nextRec, font=("cambria",13,"bold"))
b3.grid(row=9, column=2)
b4 = tk.Button(tab1, width="8", text=">|", command=lastRec, font=("cambria",13,"bold"))
b4.grid(row=9, column=3)
b5 = tk.Button(tab1, width="10",text="ADD", command=addRec, font=("cambria",13,"bold"))
b5.grid(row=10, column=0, padx=10, pady=10)
b6 = tk.Button(tab1,width="10",text="DELETE", command=delRec, font=("cambria",13,"bold"))
b6.grid(row=10,column=1)
b7 = tk.Button(tab1, width="10", text="UPDATE", command=updateRec, font=("cambria",13,"bold"))
b7.grid(row=10,column=2)
b8 = tk.Button(tab1, width="10", text="CLEAR ALL", command=clear, font=("cambria",13,"bold"))
b8.grid(row=10,column=3)


l5 = tk.Label(tab1 ,text=str(count)+"/"+str(tot_rec),font=("cambria",15,"bold"),bg="white", width=20, anchor="c")
l5.grid(row=11,column=1,columnspan=2)
l5.configure(text=str(count)+"/"+str(tot_rec))

form.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-1d269dc64cad>", line 180, in delRec
#     characters_df.to_csv('./characters_stats.csv')
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py", line 3228, in to_csv
#     formatter.save()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py", line 183, in save
#     compression=self.compression,
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\common.py", line 399, in _get_handle
#     f = open(path_or_buf, mode, encoding=encoding, newline="")
# PermissionError: [Errno 13] Permission denied: './characters_stats.csv'

# %%
characters_df.index[characters_df['Name'] == "x"].tolist()[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-c6dec96d4c4b> in <module>
# ----> 1 characters_df.index[characters_df['Name'] == "x"].tolist()[0]
#
# IndexError: list index out of range

# %%
sys.maxsize
# Out:
# 9223372036854775807

# %%
x = ["a",]

# %%
len(x)
# Out:
# 1

# %%
import tkinter as tk
form = tk.Tk()
from tkinter import colorchooser

rgb_color, web_color = colorchooser.askcolor(parent=form,
                                             initialcolor=(255, 0, 0))
